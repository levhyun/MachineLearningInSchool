# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig=plt.figure()
ax=fig.add_subplot(1,1,1)   
labels=['eng','math']
x=[3,4]
y=[1,2]
ax.bar(x,y, tick_label=labels)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig=plt.figure()
ax=fig.add_subplot(1,1,1)   
labels=['eng','math']
x=[3,4]
y=[1,2]
ax.bar(x,y, tick_label=labels, color=['red','blue'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig=plt.figure()
ax=fig.add_subplot(1,1,1)   
labels=['eng','math']
x=[3,4]
y=[1,2]
ax.bar(x,y, tick_label=labels, color=['red','blue'])
for i , v in enumerate(y):
    ax.text(v+2, i+1.05,str(v),color='blue',fontweight='bold')
plt.show()s
