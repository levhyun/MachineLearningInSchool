# %%
import gdown

gdown.download('https://bit.ly/3pK7iuu', 'ns_book7.csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3pK7iuu
# To: c:\Users\g8808\Documents\GitHub\MachineLearningInSchool\2023.04.25\ns_book7.csv
# 100%|██████████| 53.8M/53.8M [00:10<00:00, 5.22MB/s]
# 'ns_book7.csv'

# %%
import pandas as pd

ns_book7 = pd.read_csv('ns_book7.csv', low_memory=False)
ns_book7.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
count_by_year = ns_book7['발행년도'].value_counts()
count_by_year
# Out:
# 2012    18601
# 2014    17797
# 2009    17611
# 2011    17523
# 2010    17503
#         ...
# 2650        1
# 2108        1
# 2104        1
# 2560        1
# 1947        1
# Name: 발행년도, Length: 87, dtype: int64

# %%
count_by_year = count_by_year.sort_index()
count_by_year
# Out:
# 1947     1
# 1948     1
# 1949     1
# 1952    11
# 1954     1
#         ..
# 2551     1
# 2552     2
# 2559     1
# 2560     1
# 2650     1
# Name: 발행년도, Length: 87, dtype: int64

# %%
count_by_year = count_by_year[count_by_year.index <= 2030]
count_by_year
# Out:
# 1947        1
# 1948        1
# 1949        1
# 1952       11
# 1954        1
#         ...
# 2020    11834
# 2021     1255
# 2025        1
# 2028        1
# 2030        1
# Name: 발행년도, Length: 68, dtype: int64

# %%
import numpy as np

def kbc_1st_char(no):
    if no is np.nan:
        return '-1'
    else:
        return no[0]

count_by_subject = ns_book7['주제분류번호'].apply(kbc_1st_char).value_counts()
count_by_subject
# Out:
# 8     108643
# 3      80767
# 5      40916
# 9      26375
# 6      25070
# 1      22647
# -1     16978
# 7      15836
# 4      13688
# 2      13474
# 0      12376
# Name: 주제분류번호, dtype: int64

# %%
ns_book7.loc[~ns_book7['주제분류번호'].isna()].head(12)
# Out:
#     번호                  도서명                        저자           출판사  발행년도  \
# 30  31               적자의 본질        스테파니 켈튼 지음, 이가영 옮김         비즈니스맵  2021
# 31  32     한 권으로 배우는 음악 이야기                    전기홍 지음          상상출판  2021
# 32  33                인간 관찰       구라하시 마야코 지음, 황세정 옮김         쌤앤파커스  2021
# 33  34               정원의 쓸모     수 스튜어트 스미스 지음, 고정아 옮김            윌북  2021
# 34  35  뇌는 당신이 왜 우울한지 알고 있다  야오나이린 지음, 정세경 옮김, 전홍진 감수          더퀘스트  2021
# 35  36                노후 수업                    박중언 지음          휴(休)  2021
# 36  37            스마트한 원격수업         (사)디지털리터러시교육협회 지음           성안당  2021
# 37  38              진화의 오리진  존 그리빈.메리 그리빈 지음, 권루시안 옮김   진선북스(진선출판사)  2021
# 38  39        뇌는 작아지고 싶어 한다         브루스 후드 지음, 조은영 옮김  알에이치코리아(RHK)  2021
# 39  40             벼랑 끝의 파리        메리 매콜리프 지음, 최애리 옮김           현암사  2021
# 40  41         2차 세계대전의 민중사       도니 글룩스타인 지음, 김덕련 옮김          오월의봄  2021
# 41  42              피에 젖은 땅       티머시 스나이더 지음, 함규진 옮김          글항아리  2021
#
#              ISBN 세트 ISBN 부가기호    권    주제분류번호  도서권수  대출건수        등록일자
# 30  9788986022292     NaN  NaN  NaN    327.04     1     1  2021-03-16
# 31  9791190938617     NaN  NaN  NaN     670.4     1     1  2021-03-16
# 32  9791165343125     NaN  NaN  NaN     189.2     1     1  2021-03-16
# 33  9791155813478     NaN  NaN  NaN     525.3     1     1  2021-03-16
# 34  9791165214821     NaN  NaN  NaN     181.3     1     1  2021-03-16
# 35  9791160404630     NaN  NaN  NaN     199.1     1     1  2021-03-16
# 36  9788931556681     NaN  NaN  NaN   005.567     1     0  2021-03-16
# 37  9791190779272     NaN  NaN  NaN     443.1     1     0  2021-03-16
# 38  9788925589121     NaN  NaN  NaN  511.1813     1     0  2021-03-16
# 39  9788932321226     NaN  NaN  NaN    609.11     1     0  2021-03-16
# 40  9791190422635     NaN  NaN  NaN    909.54     1     1  2021-03-16
# 41  9788967358716     NaN  NaN  NaN     920.5     1     1  2021-03-16

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.dpi'] = 100

# %%
plt.plot(count_by_year.index, count_by_year.values)
plt.title('Book by year')
plt.xlabel('year')
plt.ylabel('number of books')   
plt.show()

# %%
plt.plot(count_by_year, marker='.', linestyle=':', color='red')
# plt.plot(count_by_year, '.:r')
plt.title('Book by year')
plt.xlabel('year')
plt.ylabel('number of books')   
plt.show()

# %%
plt.plot(count_by_year, '*-g')
plt.title('Book by year')
plt.xlabel('year')
plt.ylabel('number of books')   
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
    plt.annotate(val, (idx, val))
plt.show()

# %%
plt.plot(count_by_year, '*-g')
plt.title('Book by year')
plt.xlabel('year')
plt.ylabel('number of books')   
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
    plt.annotate(val, (idx, val), xytext=(idx+1, val+10))
plt.show()

# %%
plt.plot(count_by_year, '*-g')
plt.title('Book by year')
plt.xlabel('year')
plt.ylabel('number of books')
plt.xticks(range(1947, 2030, 10))
for idx, val in count_by_year[::5].items():
    plt.annotate(val, (idx, val), xytext=(2, 2), textcoords='offset points')
plt.show()

# %%
plt.bar(count_by_subject.index, count_by_subject.values)
plt.title('Book by subject')
plt.xlabel('subject')
plt.ylabel('number of books')   
for idx, val in count_by_subject.items():
    plt.annotate(val, (idx, val), xytext=(0, 2), textcoords='offset points')
plt.show()

# %%
plt.bar(count_by_subject.index, count_by_subject.values, width=0.7, color='blue')
plt.title('Book by subject')
plt.xlabel('subject')
plt.ylabel('number of books')   
for idx, val in count_by_subject.items():
    plt.annotate(val, (idx, val), xytext=(0, 2), textcoords='offset points', fontsize=8, ha='center', color='green')
plt.show()

# %%
plt.barh(count_by_subject.index, count_by_subject.values, height=0.7, color='blue')
plt.title('Book by subject')
plt.xlabel('subject')
plt.ylabel('number of books')   
for idx, val in count_by_subject.items():
    plt.annotate(val, (val, idx), xytext=(2, 0), textcoords='offset points', fontsize=8, ha='center', color='green')
plt.show()

# %%
import sys

img = plt.imread('jupiter.png')
img.shape
# Out:
# (1561, 1646, 3)

# %%
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from PIL import Image

pil_img = Image.open('jupiter.png')
plt.figure(figsize=(8,6))
plt.imshow(pil_img)
plt.axis('off')
plt.show()

# %%
import numpy as np
arr_img = np.array(pil_img)
arr_img.shape
# Out:
# (1561, 1646, 3)

# %%
plt.imsave('jupiter.jpg', arr_img)

# %%
plt.rcParams['savefig.dpi']
# Out:
# 'figure'

# %%
plt.barh(count_by_subject.index, count_by_subject.values, height=0.7, color='blue')
plt.title('Book by subject')
plt.xlabel('subject')
plt.ylabel('number of books')   
for idx, val in count_by_subject.items():
    plt.annotate(val, (val, idx), xytext=(2, 0), textcoords='offset points', fontsize=8, ha='center', color='green')
plt.savefig('book_by_subject.png')
plt.show()

# %%
pil_img = Image.open('book_by_subject.png')
plt.figure(figsize=(8,6))
plt.imshow(pil_img)
plt.axis('off')
plt.show()

# %%
GraphImage = plt.imread('book_by_subject.png')
plt.figure(figsize=(8, 6))
plt.imshow(GraphImage)
plt.axis('off')
plt.show()
