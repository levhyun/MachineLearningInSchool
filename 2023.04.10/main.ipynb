# %%
import matplotlib.pyplot as plt

x = range(0,10)
y = range(5,15)
plt.plot(x,y,'ro')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1) 
ax2 = fig.add_subplot(1, 2, 2) 
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1) 
ax2 = fig.add_subplot(2, 2, 2)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1) 
ax2 = fig.add_subplot(1, 2, 2) 
ax1.plot(range(0,10),range(5,15),'ro')
ax2.plot(range(0,50),range(0,50),'bs')
plt.xlabel('qty')
plt.ylabel('qty')
plt.show()

# %%
plt.title('Ku jahyun')
plt.plot([x for x in range(4)])
plt.xlabel('x line')
plt.ylabel('y line')
plt.show()
